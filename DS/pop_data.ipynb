# %%
import pandas as pd
df= pd.read_csv('AI_Impact_on_Jobs_2030.csv')
df.head()
# Out:
#              Job_Title  Average_Salary  Years_Experience Education_Level  \
# 0       Security Guard           45795                28        Master's
# 1   Research Scientist          133355                20             PhD
# 2  Construction Worker          146216                 2     High School
# 3    Software Engineer          136530                13             PhD
# 4    Financial Analyst           70397                22     High School
#
#    AI_Exposure_Index  Tech_Growth_Factor  Automation_Probability_2030  \
# 0               0.18                1.28                         0.85
# 1               0.62                1.11                         0.05
# 2               0.86                1.18                         0.81
# 3               0.39                0.68                         0.60
# 4               0.52                1.46                         0.64
#
#   Risk_Category  Skill_1  Skill_2  Skill_3  Skill_4  Skill_5  Skill_6  \
# ...

# %%
df= pd.read_csv('2023_Countries by Population.csv')
df.head()
# Out:
#    place      pop1980       pop2000       pop2010       pop2022       pop2023  \
# 0    356  696828385.0  1.059634e+09  1.240614e+09  1.417173e+09  1.428628e+09
# 1    156  982372466.0  1.264099e+09  1.348191e+09  1.425887e+09  1.425671e+09
# 2    840  223140018.0  2.823986e+08  3.111828e+08  3.382899e+08  3.399966e+08
# 3    360  148177096.0  2.140724e+08  2.440162e+08  2.755013e+08  2.775341e+08
# 4    586   80624057.0  1.543699e+08  1.944545e+08  2.358249e+08  2.404857e+08
#
#         pop2030       pop2050        country       area  landAreaKm cca2 cca3  \
# 0  1.514994e+09  1.670491e+09          India  3287590.0   2973190.0   IN  IND
# 1  1.415606e+09  1.312636e+09          China  9706961.0   9424702.9   CN  CHN
# 2  3.521623e+08  3.753920e+08  United States  9372610.0   9147420.0   US  USA
# 3  2.921501e+08  3.172252e+08      Indonesia  1904569.0   1877519.0   ID  IDN
# 4  2.740298e+08  3.678085e+08       Pakistan   881912.0    770880.0   PK  PAK
#
# ...

# %%
df.columns
# Out:
# Index(['place', 'pop1980', 'pop2000', 'pop2010', 'pop2022', 'pop2023',
#        'pop2030', 'pop2050', 'country', 'area', 'landAreaKm', 'cca2', 'cca3',
#        'netChange', 'growthRate', 'worldPercentage', 'density', 'densityMi',
#        'rank'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   place            234 non-null    int64
#  1   pop1980          234 non-null    float64
#  2   pop2000          234 non-null    float64
#  3   pop2010          234 non-null    float64
#  4   pop2022          234 non-null    float64
#  5   pop2023          234 non-null    float64
#  6   pop2030          234 non-null    float64
#  7   pop2050          234 non-null    float64
#  8   country          234 non-null    object
#  9   area             234 non-null    float64
#  10  landAreaKm       234 non-null    float64
#  11  cca2             233 non-null    object
#  12  cca3             234 non-null    object
#  13  netChange        226 non-null    float64
#  14  growthRate       234 non-null    float64
#  15  worldPercentage  228 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# place              0
# pop1980            0
# pop2000            0
# pop2010            0
# pop2022            0
# pop2023            0
# pop2030            0
# pop2050            0
# country            0
# area               0
# landAreaKm         0
# cca2               1
# cca3               0
# netChange          8
# growthRate         0
# worldPercentage    6
# density            0
# densityMi          0
# rank               0
# dtype: int64

# %%
# to find population of 2025

oneyear= df.loc[:,'pop2023']*df.loc[:,'growthRate']
two=oneyear*2
two
# Out:
# 0      2.314377e+07
# 1     -5.702685e+05
# 2      3.399966e+06
# 3      4.107505e+06
# 4      9.523232e+06
#            ...
# 229   -7.894800e+00
# 230    2.198780e+01
# 231    1.935000e+00
# 232    4.467480e+01
# 233    1.626520e+01
# Length: 234, dtype: float64

# %%
df.loc[:,'pop2023']+two
# Out:
# 0      1.451771e+09
# 1      1.425101e+09
# 2      3.433965e+08
# 3      2.816416e+08
# 4      2.500089e+08
#            ...
# 229    4.378105e+03
# 230    3.812988e+03
# 231    1.936935e+03
# 232    1.937675e+03
# 233    5.342652e+02
# Length: 234, dtype: float64

# %%
df.insert(loc=6,column='pop2025', value=df.loc[:,'pop2023']+two)

# %%
df.head(10)
# Out:
#    place      pop1980       pop2000       pop2010       pop2022       pop2023  \
# 0    356  696828385.0  1.059634e+09  1.240614e+09  1.417173e+09  1.428628e+09
# 1    156  982372466.0  1.264099e+09  1.348191e+09  1.425887e+09  1.425671e+09
# 2    840  223140018.0  2.823986e+08  3.111828e+08  3.382899e+08  3.399966e+08
# 3    360  148177096.0  2.140724e+08  2.440162e+08  2.755013e+08  2.775341e+08
# 4    586   80624057.0  1.543699e+08  1.944545e+08  2.358249e+08  2.404857e+08
# 5    566   72951439.0  1.228520e+08  1.609529e+08  2.185412e+08  2.238046e+08
# 6     76  122288383.0  1.758737e+08  1.963535e+08  2.153135e+08  2.164224e+08
# 7     50   83929765.0  1.291933e+08  1.483911e+08  1.711864e+08  1.729543e+08
# 8    643  138257420.0  1.468448e+08  1.432426e+08  1.447133e+08  1.444444e+08
# 9    484   67705186.0  9.787344e+07  1.125324e+08  1.275041e+08  1.284556e+08
#
#         pop2025       pop2030       pop2050        country        area  \
# ...

# %%
# df.loc[:,'pop2023']-oneyear

# %%
df[df.loc[:,'worldPercentage'].isnull()]
# Out:
#      place  pop1980  pop2000  pop2010  pop2022  pop2023    pop2025  pop2030  \
# 228    666   6106.0   6274.0   6052.0   5862.0   5840.0  5795.6160   5651.0
# 229    500  11452.0   5138.0   4938.0   4390.0   4386.0  4378.1052   4301.0
# 230    238   2240.0   3080.0   3187.0   3780.0   3791.0  3812.9878   3869.0
# 231    570   3637.0   2074.0   1812.0   1934.0   1935.0  1936.9350   1948.0
# 232    772   1647.0   1666.0   1367.0   1871.0   1893.0  1937.6748   2046.0
# 233    336    733.0    651.0    596.0    510.0    518.0   534.2652    561.0
#
#      pop2050                    country      area  landAreaKm cca2 cca3  \
# 228   5165.0  Saint Pierre and Miquelon    242.00      242.00   PM  SPM
# 229   3781.0                 Montserrat    102.00      102.00   MS  MSR
# 230   3779.0           Falkland Islands  12173.00    12173.00   FK  FLK
# 231   2096.0                       Niue    261.00      261.00   NU  NIU
# 232   2430.0                    Tokelau     12.00       10.00   TK  TKL
# ...

# %%
df.loc[:,'pop2023'].sum()
# Out:
# 8043615390.0

# %%
df.loc[0,'pop2023']
# Out:
# 1428627663.0

# %%
(1428627663/8043615390)
# Out:
# 0.177610140929426

# %%
null_index= df[df.loc[:,'worldPercentage'].isnull()].index

# %%
null_index
# Out:
# Index([228, 229, 230, 231, 232, 233], dtype='int64')

# %%
values = df.loc[null_index,'pop2023']/df.loc[:,'pop2023'].sum()

# %%
values
# Out:
# 228    7.260417e-07
# 229    5.452772e-07
# 230    4.713055e-07
# 231    2.405635e-07
# 232    2.353419e-07
# 233    6.439890e-08
# Name: pop2023, dtype: float64

# %%
df.loc[null_index,'worldPercentage']=values

# %%
# df.isnull().sum()

# %%
newdf= df[df.netChange.isnull()]
newdf.head(2)
# Out:
#      place  pop1980  pop2000  pop2010  pop2022  pop2023     pop2025  pop2030  \
# 217    674  21346.0  26823.0  31608.0  33660.0  33642.0  33608.3580  33458.0
# 221    585  12252.0  19726.0  18540.0  18055.0  18058.0  18065.2232  17919.0
#
#      pop2050     country   area  landAreaKm cca2 cca3  netChange  growthRate  \
# 217  32044.0  San Marino   61.0        60.0   SM  SMR        NaN     -0.0005
# 221  16689.0       Palau  459.0       460.0   PW  PLW        NaN      0.0002
#
#      worldPercentage   density  densityMi  rank
# 217              0.0  560.7000  1452.2130   218
# 221              0.0   39.2565   101.6744   222

# %%
net_null= df[df.netChange.isnull()].index

# %%
net_null
# Out:
# Index([217, 221, 227, 228, 229, 230, 232, 233], dtype='int64')

# %%
a= [(newdf.loc[:,'pop2000'] - newdf.loc[:,'pop1980'])/20,(newdf.loc[:,'pop2010'] - newdf.loc[:,'pop2000'])/10,(newdf.loc[:,'pop2022'] - newdf.loc[:,'pop2010'])/12,(newdf.loc[:,'pop2023'] - newdf.loc[:,'pop2022']),(newdf.loc[:,'pop2030'] - newdf.loc[:,'pop2023'])/7,(newdf.loc[:,'pop2050'] - newdf.loc[:,'pop2030'])/20]
a
# Out:
# [217    273.85
#  221    373.70
#  227    204.95
#  228      8.40
#  229   -315.70
#  230     42.00
#  232      0.95
#  233     -4.10
#  dtype: float64,
#  217    478.5
#  221   -118.6
#  227    190.6
#  228    -22.2
#  229    -20.0
#  230     10.7
#  232    -29.9
#  233     -5.5
#  dtype: float64,
#  217    171.000000
#  221    -40.416667
#  227    164.916667
#  228    -15.833333
#  229    -45.666667
#  230     49.416667
#  232     42.000000
#  233     -7.166667
#  dtype: float64,
#  217   -18.0
#  221     3.0
#  227    27.0
#  228   -22.0
#  229    -4.0
#  230    11.0
#  232    22.0
#  233     8.0
#  dtype: float64,
#  217   -26.285714
#  221   -19.857143
#  227    17.000000
#  228   -27.000000
#  229   -12.142857
#  230    11.142857
#  232    21.857143
#  233     6.142857
#  dtype: float64,
#  217   -70.70
#  221   -61.50
#  227   -45.15
#  228   -24.30
#  229   -26.00
#  230    -4.50
#  232    19.20
#  233     8.50
#  dtype: float64]

# %%
nulldf= pd.DataFrame(a)

# %%
nulldf
# Out:
#           217         221         227        228         229        230  \
# 0  273.850000  373.700000  204.950000   8.400000 -315.700000  42.000000
# 1  478.500000 -118.600000  190.600000 -22.200000  -20.000000  10.700000
# 2  171.000000  -40.416667  164.916667 -15.833333  -45.666667  49.416667
# 3  -18.000000    3.000000   27.000000 -22.000000   -4.000000  11.000000
# 4  -26.285714  -19.857143   17.000000 -27.000000  -12.142857  11.142857
# 5  -70.700000  -61.500000  -45.150000 -24.300000  -26.000000  -4.500000
#
#          232       233
# 0   0.950000 -4.100000
# 1 -29.900000 -5.500000
# 2  42.000000 -7.166667
# 3  22.000000  8.000000
# 4  21.857143  6.142857
# 5  19.200000  8.500000

# %%
nulldf.mean()
# Out:
# 217    134.727381
# 221     22.721032
# 227     93.219444
# 228    -17.155556
# 229    -70.584921
# 230     19.959921
# 232     12.684524
# 233      0.979365
# dtype: float64

# %%
result= nulldf.mean()/1000

# %%
result
# Out:
# 217    0.134727
# 221    0.022721
# 227    0.093219
# 228   -0.017156
# 229   -0.070585
# 230    0.019960
# 232    0.012685
# 233    0.000979
# dtype: float64

# %%
df.loc[net_null,'netChange']=result

# %%
df.isnull().sum()
# Out:
# place              0
# pop1980            0
# pop2000            0
# pop2010            0
# pop2022            0
# pop2023            0
# pop2025            0
# pop2030            0
# pop2050            0
# country            0
# area               0
# landAreaKm         0
# cca2               1
# cca3               0
# netChange          0
# growthRate         0
# worldPercentage    0
# density            0
# densityMi          0
# rank               0
# dtype: int64

# %%
df.loc[net_null,:]
# Out:
#      place  pop1980  pop2000  pop2010  pop2022  pop2023     pop2025  pop2030  \
# 217    674  21346.0  26823.0  31608.0  33660.0  33642.0  33608.3580  33458.0
# 221    585  12252.0  19726.0  18540.0  18055.0  18058.0  18065.2232  17919.0
# 227    652   2983.0   7082.0   8988.0  10967.0  10994.0  11048.9700  11113.0
# 228    666   6106.0   6274.0   6052.0   5862.0   5840.0   5795.6160   5651.0
# 229    500  11452.0   5138.0   4938.0   4390.0   4386.0   4378.1052   4301.0
# 230    238   2240.0   3080.0   3187.0   3780.0   3791.0   3812.9878   3869.0
# 232    772   1647.0   1666.0   1367.0   1871.0   1893.0   1937.6748   2046.0
# 233    336    733.0    651.0    596.0    510.0    518.0    534.2652    561.0
#
#      pop2050                    country      area  landAreaKm cca2 cca3  \
# 217  32044.0                 San Marino     61.00       60.00   SM  SMR
# 221  16689.0                      Palau    459.00      460.00   PW  PLW
# ...
