# %%
import pandas as pd 
# dataframes - rows, columns, 2D

# %%
df= pd.DataFrame([[12,24,30],[41,53,60]])
df
# Out:
#     0   1   2
# 0  12  24  30
# 1  41  53  60

# %%
# dictionary

# %%
df=pd.DataFrame({'name':['Anurag','Arun','Ansh','Nikhil','Gautum','Ram'], 'rollno':[2,4,3,1,10,45],'class':['bba','mba','bba','btech','bca','mca']})
df
# Out:
#      name  rollno  class
# 0  Anurag       2    bba
# 1    Arun       4    mba
# 2    Ansh       3    bba
# 3  Nikhil       1  btech
# 4  Gautum      10    bca
# 5     Ram      45    mca

# %%
df.head() #first 5 bydefault
# Out:
#      name  rollno  class
# 0  Anurag       2    bba
# 1    Arun       4    mba
# 2    Ansh       3    bba
# 3  Nikhil       1  btech
# 4  Gautum      10    bca

# %%
df.head(2)
# Out:
#      name  rollno class
# 0  Anurag       2   bba
# 1    Arun       4   mba

# %%
df.tail()  # by default last 5
df.tail(3)
# Out:
#      name  rollno  class
# 3  Nikhil       1  btech
# 4  Gautum      10    bca
# 5     Ram      45    mca

# %%
# access 
# loc, iloc 
# [], .

# %%
df['name']
# Out:
# 0    Anurag
# 1      Arun
# 2      Ansh
# 3    Nikhil
# 4    Gautum
# 5       Ram
# Name: name, dtype: object

# %%
df['class']
# Out:
# 0      bba
# 1      mba
# 2      bba
# 3    btech
# 4      bca
# 5      mca
# Name: class, dtype: object

# %%
df['name'][4]
# Out:
# 'Gautum'

# %%
df.name[4]
# Out:
# 'Gautum'

# %%
df['class'][:3]
# Out:
# 0    bba
# 1    mba
# 2    bba
# Name: class, dtype: object

# %%
df[['name','class']][:3]
# Out:
#      name class
# 0  Anurag   bba
# 1    Arun   mba
# 2    Ansh   bba

# %%
df
# Out:
#      name  rollno  class
# 0  Anurag       2    bba
# 1    Arun       4    mba
# 2    Ansh       3    bba
# 3  Nikhil       1  btech
# 4  Gautum      10    bca
# 5     Ram      45    mca

# %%
# loc, iloc
df.loc[:,:]  # rows, columns
# Out:
#      name  rollno  class
# 0  Anurag       2    bba
# 1    Arun       4    mba
# 2    Ansh       3    bba
# 3  Nikhil       1  btech
# 4  Gautum      10    bca
# 5     Ram      45    mca

# %%
df.loc[:,'name']
# Out:
# 0    Anurag
# 1      Arun
# 2      Ansh
# 3    Nikhil
# 4    Gautum
# 5       Ram
# Name: name, dtype: object

# %%
df.loc[:,['name','class']]
# Out:
#      name  class
# 0  Anurag    bba
# 1    Arun    mba
# 2    Ansh    bba
# 3  Nikhil  btech
# 4  Gautum    bca
# 5     Ram    mca

# %%
df.loc[:3,['name']]
# Out:
#      name
# 0  Anurag
# 1    Arun
# 2    Ansh
# 3  Nikhil

# %%
# df.loc[1:,'name']

# %%
df.iloc[:3,:]
# Out:
#      name  rollno class
# 0  Anurag       2   bba
# 1    Arun       4   mba
# 2    Ansh       3   bba

# %%
df.iloc[:4,:2]
# Out:
#      name  rollno
# 0  Anurag       2
# 1    Arun       4
# 2    Ansh       3
# 3  Nikhil       1

# %%
df.loc[:,'totalmarks']=120
df
# Out:
#      name  rollno  class  totalmarks  marks
# 0  Anurag       2    bba         120     87
# 1    Arun       4    mba         120     56
# 2    Ansh       3    bba         120     77
# 3  Nikhil       1  btech         120     99
# 4  Gautum      10    bca         120     73
# 5     Ram      45    mca         120     67

# %%
df.loc[:,'marks']=[87,56,77,99,73,67]
df
# Out:
#      name  rollno  class  totalmarks  marks
# 0  Anurag       2    bba         120     87
# 1    Arun       4    mba         120     56
# 2    Ansh       3    bba         120     77
# 3  Nikhil       1  btech         120     99
# 4  Gautum      10    bca         120     73
# 5     Ram      45    mca         120     67

# %%
#delete 
# df.drop('totalmarks', axis=1, inplace=True)

# %%
df
# Out:
#      name  rollno  class  marks
# 0  Anurag       2    bba     87
# 1    Arun       4    mba     56
# 2    Ansh       3    bba     77
# 3  Nikhil       1  btech     99
# 4  Gautum      10    bca     73
# 5     Ram      45    mca     67

# %%
df[df.loc[:,'class']=='bba']
# Out:
#      name  rollno class  marks
# 0  Anurag       2   bba     87
# 2    Ansh       3   bba     77

# %%
df[(df.loc[:,'class']=='bba') | (df.loc[:,'marks']>80)]
# Out:
#      name  rollno  class  marks
# 0  Anurag       2    bba     87
# 2    Ansh       3    bba     77
# 3  Nikhil       1  btech     99

# %%
# null values, duplicates find, nullvalues drop, fill, insert, rename
