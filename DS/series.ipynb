# %%
# Pandas, numpy 
# pandas - 2 types of data structures - dataframes, series 
# series 1d, dataframes 2d
print("Hello")
# Out:
# Hello

# %%
print("hi")
# Out:
# hi

# %%
print(13+400)
# Out:
# 413

# %%
a=20
b=30

# %%
print(a+b)
# Out:
# 50
