# %%
import pandas as pd

# %%
# list, dictionary
series= pd.Series([13,56,55,33,100])
series
# Out:
# 0     13
# 1     56
# 2     55
# 3     33
# 4    100
# dtype: int64

# %%
series1= pd.Series([13,56,55,0,100], index=['a','b','c','d','e'], dtype='bool')
series1
# Out:
# a     True
# b     True
# c     True
# d    False
# e     True
# dtype: bool

# %%
series1= pd.Series([13,56,55,0,100], index=['a','b','c','d','e'], dtype='float')
series1
# Out:
# a     13.0
# b     56.0
# c     55.0
# d      0.0
# e    100.0
# dtype: float64

# %%
# with list comprehension
ser2= pd.Series([i for i in range(10,20)])
ser2
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# 5    15
# 6    16
# 7    17
# 8    18
# 9    19
# dtype: int64

# %%
# access [], .  
ser2[:4]
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# dtype: int64

# %%
ser2[2]
# Out:
# 12

# %%
# ser2.4 # error
# number index -- always in []
# character or string index in [' '], .

# %%
series1.a
# Out:
# 13.0

# %%
series1['b']
# Out:
# 56.0

# %%
series[1]
# Out:
# 56

# %%
series1.d
# Out:
# 0.0

# %%
# loc, iloc -- location or indexlocation

# %%
ser2
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# 5    15
# 6    16
# 7    17
# 8    18
# 9    19
# dtype: int64

# %%
ser2.loc[:4]  # loc start stop nahi challega because yeh as a label hi dekhta hai chaahe index ho
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# dtype: int64

# %%
ser2.iloc[:4]
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# dtype: int64

# %%
series1.loc['a']
# Out:
# 13.0

# %%
series1.iloc[0]
# Out:
# 13.0

# %%
# add, update, delete - in series

# %%
series1
# Out:
# a     13.0
# b     56.0
# c     55.0
# d      0.0
# e    100.0
# dtype: float64

# %%
series1['e']=50

# %%
series1
# Out:
# a    13.0
# b    56.0
# c    55.0
# d     0.0
# e    50.0
# dtype: float64

# %%
series
# Out:
# 0     13
# 1     56
# 2     55
# 3     33
# 4    100
# dtype: int64

# %%
series.loc[5]=49

# %%
series
# Out:
# 0     13
# 1     56
# 2     55
# 3     33
# 4    100
# 5     49
# dtype: int64

# %%
series.drop(5)
# Out:
# 0     13
# 1     56
# 2     55
# 3     33
# 4    100
# dtype: int64

# %%
series.drop(5,inplace=True)

# %%
series
# Out:
# 0     13
# 1     56
# 2     55
# 3     33
# 4    100
# dtype: int64

# %%
# Nan Values - not a number 

ser3= pd.Series([34,None,55,None,100,70,None, 15])
ser3
# Out:
# 0     34.0
# 1      NaN
# 2     55.0
# 3      NaN
# 4    100.0
# 5     70.0
# 6      NaN
# 7     15.0
# dtype: float64

# %%
ser3.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7    False
# dtype: bool

# %%
ser3.isna()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7    False
# dtype: bool

# %%
ser3[ser3.isnull()]
# Out:
# 1   NaN
# 3   NaN
# 6   NaN
# dtype: float64

# %%
ser3.hasnans
# Out:
# True

# %%
ser3.isnull().any()
# Out:
# True

# %%
ser3.isnull().sum()
# Out:
# 3

# %%
ser3.dropna()
# Out:
# 0     34.0
# 2     55.0
# 4    100.0
# 5     70.0
# 7     15.0
# dtype: float64

# %%
ser3.dropna(ignore_index= True)
# Out:
# 0     34.0
# 1     55.0
# 2    100.0
# 3     70.0
# 4     15.0
# dtype: float64

# %%
# ser3.fillna(ser3.mean())
ser3.fillna(ser3.mean(), inplace=True)

# %%
ser3
# Out:
# 0     34.0
# 1     54.8
# 2     55.0
# 3     54.8
# 4    100.0
# 5     70.0
# 6     54.8
# 7     15.0
# dtype: float64

# %%
ser3.sum()
# Out:
# 438.4

# %%
ser3.mean()
# Out:
# 54.8

# %%
ser3.median()
# Out:
# 54.8

# %%
ser3.mode()
# Out:
# 0    54.8
# dtype: float64
