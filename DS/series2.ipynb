# %%
import pandas as pd

# %%
ser=pd.Series([12,56,55,23,100,43,39])
ser
# Out:
# 0     12
# 1     56
# 2     55
# 3     23
# 4    100
# 5     43
# 6     39
# dtype: int64

# %%
(ser>10) & (ser<20)
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
ser[(ser>10) & (ser<20)]
# Out:
# 0    12
# dtype: int64

# %%
#functions - between 
ser[ser.between(10,50)]
# Out:
# 0    12
# 3    23
# 5    43
# 6    39
# dtype: int64

# %%
ser[ser.between(12,50, inclusive='right')]
# Out:
# 3    23
# 5    43
# 6    39
# dtype: int64

# %%
ser[ser==43]
# Out:
# 5    43
# dtype: int64

# %%
ser[ser.isin([43])]
# Out:
# 5    43
# dtype: int64

# %%
ser[ser.isin([43])].index
# Out:
# Index([5], dtype='int64')

# %%
ser[ser.isin([43])].values
# Out:
# array([43], dtype=int64)

# %%
ser.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
ser2=pd.Series({'name':'Gurminder','class':'btech','rollno':10})
# ser2=pd.Series({'name':'Gurminder','class':'btech','rollno':10}, index=['name','marks'])
ser2
# Out:
# name      Gurminder
# class         btech
# rollno           10
# dtype: object

# %%
ser2.index
# Out:
# Index(['name', 'class', 'rollno'], dtype='object')

# %%
ser2.values
# Out:
# array(['Gurminder', 'btech', 10], dtype=object)

# %%
ser3= pd.Series([12,56,44,78,56,12,100,55,43])
ser3
# Out:
# 0     12
# 1     56
# 2     44
# 3     78
# 4     56
# 5     12
# 6    100
# 7     55
# 8     43
# dtype: int64

# %%
ser3.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
ser3[ser3.duplicated()]
# Out:
# 4    56
# 5    12
# dtype: int64

# %%
# ser3.drop_duplicates()
ser3.drop_duplicates(inplace=True, ignore_index=True)

# %%
ser3
# Out:
# 0     12
# 1     56
# 2     44
# 3     78
# 4    100
# 5     55
# 6     43
# dtype: int64

# %%
s1=pd.Series([14,56,77,88,100])
s2=pd.Series([1,5,7,88])

# %%
pd.concat((s1,s2), ignore_index=True)
# Out:
# 0     14
# 1     56
# 2     77
# 3     88
# 4    100
# 5      1
# 6      5
# 7      7
# 8     88
# dtype: int64

# %%
s1.tolist()
# Out:
# [14, 56, 77, 88, 100]

# %%
def add2(a):
    return a+2

# %%
s1
# Out:
# 0     14
# 1     56
# 2     77
# 3     88
# 4    100
# dtype: int64

# %%
s1.map(add2)
# Out:
# 0     16
# 1     58
# 2     79
# 3     90
# 4    102
# dtype: int64

# %%
s1
# Out:
# 0     14
# 1     56
# 2     77
# 3     88
# 4    100
# dtype: int64
