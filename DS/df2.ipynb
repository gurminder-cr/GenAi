# %%
import pandas as pd

# %%
df=pd.DataFrame({'name':['Anurag','Arun','Ansh','Nikhil','Gautum','Ram'], 'rollno':[2,4,3,1,10,45],'class':['bba','mba','bba','btech','bca','mca']})
df
# Out:
#      name  rollno  class
# 0  Anurag       2    bba
# 1    Arun       4    mba
# 2    Ansh       3    bba
# 3  Nikhil       1  btech
# 4  Gautum      10    bca
# 5     Ram      45    mca

# %%
# df.insert(loc=2,column='marks', value=[45,22,19,32,47,39])

# %%
df
# Out:
#      name  rollno  marks  class
# 0  Anurag       2     45    bba
# 1    Arun       4     22    mba
# 2    Ansh       3     19    bba
# 3  Nikhil       1     32  btech
# 4  Gautum      10     47    bca
# 5     Ram      45     39    mca

# %%
# df.insert(loc=2,column='marks', value=[45,22,19,32,47,39], allow_duplicates=True)

# %%
# df.rename(columns={'class':'degree','marks':'totalmarks'})
df.rename(columns={'class':'degree'}, inplace=True)

# %%
df
# Out:
#      name  rollno  marks degree
# 0  Anurag       2     45    bba
# 1    Arun       4     22    mba
# 2    Ansh       3     19    bba
# 3  Nikhil       1     32  btech
# 4  Gautum      10     47    bca
# 5     Ram      45     39    mca

# %%
df1= pd.DataFrame([[2,3,4,5],[5,6,7,8],[11,12,45,67],[2,3,4,5],[55,32,10,1]])
df1
# Out:
#     0   1   2   3
# 0   2   3   4   5
# 1   5   6   7   8
# 2  11  12  45  67
# 3   2   3   4   5
# 4  55  32  10   1

# %%
df1[df1.duplicated()]
# Out:
#    0  1  2  3
# 3  2  3  4  5

# %%
df1.drop_duplicates()
# Out:
#     0   1   2   3
# 0   2   3   4   5
# 1   5   6   7   8
# 2  11  12  45  67
# 4  55  32  10   1

# %%
df1.drop_duplicates(inplace=True)

# %%
df1
# Out:
#     0   1   2   3
# 0   2   3   4   5
# 1   5   6   7   8
# 2  11  12  45  67
# 4  55  32  10   1

# %%
df
# Out:
#      name  rollno  marks degree
# 0  Anurag       2     45    bba
# 1    Arun       4     22    mba
# 2    Ansh       3     19    bba
# 3  Nikhil       1     32  btech
# 4  Gautum      10     47    bca
# 5     Ram      45     39    mca

# %%
import numpy as np

# %%
df2= pd.DataFrame({'name':['Anurag','Arun','Ansh','Nikhil','Gautum','Ram'], 'rollno':[2,4,3,None,10,45],'class':['bba',np.nan,'bba','btech','bca',np.nan]})

# %%
df2
# Out:
#      name  rollno  class
# 0  Anurag     2.0    bba
# 1    Arun     4.0    NaN
# 2    Ansh     3.0    bba
# 3  Nikhil     NaN  btech
# 4  Gautum    10.0    bca
# 5     Ram    45.0    NaN

# %%
df2.isnull()
# Out:
#     name  rollno  class
# 0  False   False  False
# 1  False   False   True
# 2  False   False  False
# 3  False    True  False
# 4  False   False  False
# 5  False   False   True

# %%
df2.isnull().any()
# Out:
# name      False
# rollno     True
# class      True
# dtype: bool

# %%
df2.isnull().sum()
# Out:
# name      0
# rollno    1
# class     2
# dtype: int64

# %%
df2.rollno.fillna(12)
# Out:
# 0     2.0
# 1     4.0
# 2     3.0
# 3    12.0
# 4    10.0
# 5    45.0
# Name: rollno, dtype: float64

# %%
df2[df2['class'].isnull()]
# Out:
#    name  rollno class
# 1  Arun     4.0   NaN
# 5   Ram    45.0   NaN

# %%
null_index = df2[df2['class'].isnull()].index

# %%
null_index
# Out:
# Index([1, 5], dtype='int64')

# %%
df2.loc[null_index,'class']=['bca','mba']
df2
# Out:
#      name  rollno  class
# 0  Anurag     2.0    bba
# 1    Arun     4.0    bca
# 2    Ansh     3.0    bba
# 3  Nikhil     NaN  btech
# 4  Gautum    10.0    bca
# 5     Ram    45.0    mba

# %%
df2.isnull().any()
# Out:
# name      False
# rollno     True
# class     False
# dtype: bool

# %%
df2.columns
# Out:
# Index(['name', 'rollno', 'class'], dtype='object')

# %%
df2.shape # rows, columns
# Out:
# (6, 3)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   rollno  5 non-null      float64
#  2   class   6 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 276.0+ bytes

# %%
# fill 
df.marks.mean()
# Out:
# 34.0

# %%
#file read --

# %%
df3= pd.read_csv('AI_Impact_on_Jobs_2030.csv')

# %%
df3.head()
# Out:
#              Job_Title  Average_Salary  Years_Experience Education_Level  \
# 0       Security Guard           45795                28        Master's
# 1   Research Scientist          133355                20             PhD
# 2  Construction Worker          146216                 2     High School
# 3    Software Engineer          136530                13             PhD
# 4    Financial Analyst           70397                22     High School
#
#    AI_Exposure_Index  Tech_Growth_Factor  Automation_Probability_2030  \
# 0               0.18                1.28                         0.85
# 1               0.62                1.11                         0.05
# 2               0.86                1.18                         0.81
# 3               0.39                0.68                         0.60
# 4               0.52                1.46                         0.64
#
#   Risk_Category  Skill_1  Skill_2  Skill_3  Skill_4  Skill_5  Skill_6  \
# ...

# %%
df3.columns
# Out:
# Index(['Job_Title', 'Average_Salary', 'Years_Experience', 'Education_Level',
#        'AI_Exposure_Index', 'Tech_Growth_Factor',
#        'Automation_Probability_2030', 'Risk_Category', 'Skill_1', 'Skill_2',
#        'Skill_3', 'Skill_4', 'Skill_5', 'Skill_6', 'Skill_7', 'Skill_8',
#        'Skill_9', 'Skill_10'],
#       dtype='object')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Job_Title                    3000 non-null   object
#  1   Average_Salary               3000 non-null   int64
#  2   Years_Experience             3000 non-null   int64
#  3   Education_Level              3000 non-null   object
#  4   AI_Exposure_Index            3000 non-null   float64
#  5   Tech_Growth_Factor           3000 non-null   float64
#  6   Automation_Probability_2030  3000 non-null   float64
#  7   Risk_Category                3000 non-null   object
#  8   Skill_1                      3000 non-null   float64
#  9   Skill_2                      3000 non-null   float64
#  10  Skill_3                      3000 non-null   float64
#  11  Skill_4                      3000 non-null   float64
# ...
